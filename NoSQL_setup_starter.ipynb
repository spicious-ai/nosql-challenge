# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with
# test> use uk_food
# switched to db uk_food
# uk_food> db
# uk_food
# uk_food> db.createCollection("establishments")
# { ok: 1 }
# uk_food> show collections
# uk_food> mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'epa', 'fruits_db', 'gardenDB', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641a8b4dcdabda5112bbd29f'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_halal = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_halal)

# %%
# Check that the new restaurant was inserted
query = {"BusinessName":"Penang Flavours"}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641a8b57a0d9bcd17efe5e9a'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {}
fields = {'BusinessTypeID': 1, 'BusinessType': 'Restaurant/Cafe/Canteen'}

# Capture the results to a variable
results = establishments.find(query, fields)

# Pretty print the results
for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd29f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd2ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd300')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd301')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd302')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd303')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd304')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd305')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd306')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd307')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd308')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd309')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd30a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd30b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd30c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd30d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd30e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd30f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd310')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd311')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd312')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd313')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd314')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd315')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd316')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd317')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd318')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd319')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd31a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd31b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd31c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('641a8b4dcdabda5112bbd31d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd31e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd31f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd320')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd321')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd322')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd323')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd324')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd325')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd326')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd327')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd328')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd329')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd32a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd32b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd32c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd32d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd32e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd32f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd330')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd331')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd332')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd333')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd334')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd335')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd336')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd337')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd338')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd339')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd33a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd33b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd33c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd33d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd33e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd33f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd340')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd341')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd342')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd343')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd344')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd345')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd346')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd347')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd348')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd349')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd34a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd34b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd34c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd34d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd34e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd34f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd350')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd351')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd352')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd353')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd354')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd355')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd356')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd357')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd358')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd359')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd35a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd35b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd35c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd35d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd35e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('641a8b4dcdabda5112bbd35f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd360')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd361')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd362')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd363')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd364')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd365')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd366')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd367')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd368')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd369')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd36a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd36b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd36c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd36d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd36e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd36f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd370')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd371')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd372')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd373')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd374')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd375')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd376')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd377')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd378')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd379')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd37a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd37b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd37c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd37d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd37e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd37f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd380')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd381')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd382')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd383')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd384')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd385')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd386')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd387')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd388')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd389')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd38a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd38b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd38c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd38d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd38e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd38f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd390')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd391')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd392')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd393')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd394')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd395')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd396')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd397')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd398')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd399')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd39a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd39b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd39c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd39d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd39e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd39f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd3ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('641a8b4dcdabda5112bbd400')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd401')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd402')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('641a8b4dcdabda5112bbd403')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd404')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd405')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd406')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd407')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd408')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd409')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd40a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd40b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd40c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd40d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd40e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd40f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('641a8b4dcdabda5112bbd410')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd411')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('641a8b4dcdabda5112bbd412')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd413')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('641a8b4dcdabda5112bbd414')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd415')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd416')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd417')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd418')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd419')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd41a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd41b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd41c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd41d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4dcdabda5112bbd41e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd41f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd420')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd421')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd422')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd423')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('641a8b4dcdabda5112bbd424')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4dcdabda5112bbd425')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd426')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd427')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd428')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd429')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd42a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd42b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd42c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd42d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd42e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd42f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd430')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd431')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd432')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd433')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd434')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd435')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd436')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd437')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd438')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4dcdabda5112bbd439')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd43a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd43b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4dcdabda5112bbd43c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd43d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd43e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd43f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4dcdabda5112bbd440')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4dcdabda5112bbd441')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4dcdabda5112bbd442')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4dcdabda5112bbd443')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#  '_id': ObjectId('641a8b4ecdabda5112bc3577')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc3578')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc3579')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc357a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc357b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc357c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc357d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc357e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('641a8b4ecdabda5112bc357f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc3580')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc3581')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc3582')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc3583')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc3584')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc3585')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc3586')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc3587')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc3588')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc3589')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4ecdabda5112bc358a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc358b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc358c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4ecdabda5112bc358d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc358e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc358f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc3590')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc3591')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc3592')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc3593')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4ecdabda5112bc3594')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4ecdabda5112bc3595')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4ecdabda5112bc3596')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc3597')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc3598')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc3599')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('641a8b4ecdabda5112bc359a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc359b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc359c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4ecdabda5112bc359d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc359e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc359f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4ecdabda5112bc35a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('641a8b4ecdabda5112bc35af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc35b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc35bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4ecdabda5112bc35bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4ecdabda5112bc35cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4ecdabda5112bc35cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4ecdabda5112bc35db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('641a8b4ecdabda5112bc35de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('641a8b4ecdabda5112bc35fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('641a8b4ecdabda5112bc35fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('641a8b4ecdabda5112bc35fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc35fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641a8b4ecdabda5112bc35ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('641a8b4ecdabda5112bc3600')}
# {
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({"BusinessName":"Penang Flavours"}, [ {'$set':{ "BusinessTypeID" : '1'}} ])

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName":"Penang Flavours"}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641a8b57a0d9bcd17efe5e9a'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': "Dover"}

# Print the number of results
print("Number of establishments in Dover:", establishments.count_documents(query))
# Out:
# Number of establishments in Dover: 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
myquery = { "LocalAuthorityName": "Dover" }

establishments.delete_many(myquery)

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': "Dover"}

# Print the number of results
print("Number of establishments in Dover:", establishments.count_documents(query))
# Out:
# Number of establishments in Dover: 0

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4591.871474174837,
#  'FHRSID': 289353,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6QH',
#  'RatingDate': '2016-09-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641a8b4dcdabda5112bbd583'),
#  'geocode': {'latitude': '51.085797', 'longitude': '1.194762'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289353',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude
establishments.update_many({}, [{'$set': {'geocode.longitude': {'$toDouble': '$geocode.longitude'}}}])

# %%
# Change the data type from String to Decimal for latitude
establishments.update_many({}, [{'$set': {'geocode.latitude': {'$toDouble': '$geocode.latitude'}}}])

# %%
# Check that the coordinates are now numbers
col = db["establishments"]

# Fetch records from `collection` where `key1` is of type `array`
for x in col.find({"geocode": {"$type": "array"}}):
    print(x)
